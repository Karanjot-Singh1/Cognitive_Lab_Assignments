# %% [markdown]
# ## **Assingment 1.1: WAP to print your name three times**

# %%
print("karanjot singh")
print("karanjot singh")
print("karanjot singh")
# Out:
# karanjot singh
# karanjot singh
# karanjot singh

# %% [markdown]
# **Assingment 2.1: WAP to add three numbers and print the result.**

# %%
a=2
b=3
c=5
sum=a+b+c
print("the sum of above three number are : ",sum)
# Out:
# the sum of above three number are :  10

# %% [markdown]
# **Assingment 2.2: WAP to concatinate three strings and print the result.**

# %%
a="Hello ji ! "
b="Good Morning ji, "
c="Have a good day ! "
sum=a+b+c
print("concatinated string is : ",sum)
# Out:
# concatinated string is :  Hello ji ! Good Morning ji, Have a good day !

# %% [markdown]
# **Assingment 4.1: WAP to print the table of 7, 9.**

# %%
print("table of 7 is -> ")
print()
for i in range(1,11):
  print("7 * ", i ,"  =  " , i*7)
print()
print("table of 9 is -> ")
print()
for i in range(1,11):
  print("9 * ", i ,"  =  " , i*9)
# Out:
# table of 7 is ->
#
# 7 *  1   =   7
# 7 *  2   =   14
# 7 *  3   =   21
# 7 *  4   =   28
# 7 *  5   =   35
# 7 *  6   =   42
# 7 *  7   =   49
# 7 *  8   =   56
# 7 *  9   =   63
# 7 *  10   =   70
#
# table of 9 is ->
#
# 9 *  1   =   9
# 9 *  2   =   18
# 9 *  3   =   27
# 9 *  4   =   36
# 9 *  5   =   45
# 9 *  6   =   54
# 9 *  7   =   63
# 9 *  8   =   72
# 9 *  9   =   81
# 9 *  10   =   90

# %% [markdown]
# **Assingment 4.2: WAP to print the table of n and n is given by user.**

# %%
n=int(input("enter the number to write the table"))
print("table of ", n ," is -> ")
print()
for i in range(1,11):
  print(n , " * ", i ,"  =  " , i*n)
# Out:
# enter the number to write the table12
# table of  12  is ->
#
# 12  *  1   =   12
# 12  *  2   =   24
# 12  *  3   =   36
# 12  *  4   =   48
# 12  *  5   =   60
# 12  *  6   =   72
# 12  *  7   =   84
# 12  *  8   =   96
# 12  *  9   =   108
# 12  *  10   =   120

# %% [markdown]
# **Assingment 4.3: WAP to add all the numbers from 1 to n and n is given by user.**

# %%
n=int(input("etner the ending limit "))
sum=0
for i in range(1,n+1):
  sum=sum+i
print("the sum of first n natural numbers are: ",sum)
# Out:
# etner the ending limit 10
# the sum of first n natural numbers are:  55

# %% [markdown]
# **Assingment 5.1: WAP to find max amoung three numbers and input from user. [Try max() function]**

# %%
a=int(input("enter the first number "))
b=int(input("enter the second number "))
c=int(input("enter the third number "))
max1=max(a,b)
max_ele=max(max1,c)
print("the largest among all three number is : ",max_ele)
# Out:
# enter the first number 5
# enter the second number 8
# enter the third number 6
# the largest among all three number is :  8

# %% [markdown]
# **Assingment 5.2: WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user**

# %%
n=int(input("enter the ending limit "))
sum=0
for i in range(1,n+1):
  if(i% 7==0 and i%9==0):
    sum=sum+i
print("the sum is : ",sum)
# Out:
# enter the ending limit 100
# the sum is :  63

# %% [markdown]
# **Assingment 5.3: WAP to add all prime numbers from 1 to n and n is given by the user.**

# %%
n=int(input("enter the ending limit "))
sum=0
for i in range(1,n+1):
  f=0
  for j in range(2,i//2+1):
    if(i%j==0):
      f=1
  if(f==0):
    sum=sum+i
print("the sum is : ",sum)
# Out:
# enter the ending limit 10
# the sum is :  18

# %% [markdown]
# **Assingment 6.1: WAP using function that add all odd numbers from 1 to n, n is given by the user.**

# %%
def sum_of_odd_numbers(n):
  s=0
  for i in range(1,n+1):
    if(i%2!=0):
      s=s+i
  return s

n=int(input("enter the ending limit "))
sum=sum_of_odd_numbers(n)
print("the sum is : ",sum)
# Out:
# enter the ending limit 10
# the sum is :  25

# %% [markdown]
# **Assingment 6.2: WAP using function that add all prime numbers from 1 to n, n given by the user.**

# %%
def sum_of_prime_numbers(n):
  s=0
  for i in range(1,n+1):
    f=0
    for j in range (2,i//2 +1):
      if i%j==0:
        f=1
    if(f==0):
      s=s+i
  return s

n=int(input("enter the ending limit "))
sum=sum_of_prime_numbers(n)
print("the sum is : ",sum)
# Out:
# enter the ending limit 11
# the sum is :  29
