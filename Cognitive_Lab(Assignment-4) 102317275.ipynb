# %% [markdown]
#  **Name-Karanjot Singh**
#
# **Roll No.-102317275**
#
# **Subgroup- 2Q-11**

# %% [markdown]
# Q.1 Write a program to create a NumPy 1D-array with 5 elements and perform basic
# operations like:
#
# a) Addition of 2 in all the element
#
# b) Multiply 3 with all the elements
#
# c) Divide every element by 2

# %%
import numpy as np
a=np.array([1,2,3,4,5])
print("the entered array is :")
for i in range(5):
  print(a[i],end=" ")

print()
print("adding  two in all ele")
for i in range(5):
  a[i]=a[i]+2
print("the resut is ")
for i in range(5):
  print(a[i],end=" ")
print()

print("mulitplying  by 3 in all ele")
for i in range(5):
  a[i]=a[i]*3
print("the resut is ")
for i in range(5):
  print(a[i],end=" ")
print()

print("diving  two in all ele")
for i in range(5):
  a[i]=a[i]/2
print("the resut is ")
for i in range(5):
  print(a[i],end=" ")
print()
# Out:
# the entered array is :
# 1 2 3 4 5
# adding  two in all ele
# the resut is
# 3 4 5 6 7
# mulitplying  by 3 in all ele
# the resut is
# 9 12 15 18 21
# diving  two in all ele
# the resut is
# 4 6 7 9 10

# %% [markdown]
# Q.2 Questions on Basic NumPy Array:
#
# a) Reverse the NumPy array: arr = np.array([1, 2, 3, 6, 4, 5])

# %%
import numpy as np;
arr=np.array([1,2,3,6,4,5])
print("print the original array :")
for i in range(6):
  print(arr[i],end=" ")
print()

j=5
for i in range(6//2):
  temp=arr[i]
  arr[i]=arr[j]
  arr[j]=temp
  j=j-1

print("the reverse array is : ")
for i in range(6):
  print(arr[i],end=" ")
# Out:
# print the original array :
# 1 2 3 6 4 5
# the reverse array is :
# 5 4 6 3 2 1

# %% [markdown]
# Q2 b) Find the most frequent value and their indice(s) in the following arrays:
#
# i. x = np.array([1,2,3,4,5,1,2,1,1,1])

# %%
import numpy as np;
x=np.array([1,2,3,4,5,1,2,1,1,1])
print("print the original array :")
for i in range(x.size):
  print(x[i],end=" ")
print()
max_count=0
ele=0
for i in range(x.size):
  count=0
  for j in range(i,x.size):
    if(x[j]==x[i]):
      count=count+1
    if(count>max_count):
      max_count=count
      ele=x[j]
print("max count is ")
print(max_count)
for i in range(x.size):
  if(x[i]==ele):
    print("the indeces are: ",i)
# Out:
# print the original array :
# 1 2 3 4 5 1 2 1 1 1
# max count is
# 5
# the indeces are:  0
# the indeces are:  5
# the indeces are:  7
# the indeces are:  8
# the indeces are:  9

# %% [markdown]
# Q2 b) Find the most frequent value and their indice(s) in the following arrays:
#
# ii. y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, ])

# %%
import numpy as np;
y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3])
print("print the original array :")
for i in range(y.size):
  print(y[i],end=" ")
print()
max_count=0
ele=0
for i in range(y.size):
  count=0
  for j in range(i,y.size):
    if(y[j]==y[i]):
      count=count+1
    if(count>max_count):
      max_count=count
      ele=y[j]
print("max count is ")
print(max_count)
for i in range(y.size):
  if(y[i]==ele):
    print("the indeces are: ",i)
# Out:
# print the original array :
# 1 1 1 2 3 4 2 4 3 3
# max count is
# 3
# the indeces are:  0
# the indeces are:  1
# the indeces are:  2

# %% [markdown]
# Q.3 For the given 2-D array arr=np.array([10, 20, 30], [40, 50, 60], [70, 80, 90]), access
# elements using row and column indices as follows:
#
# a) Access 1st row, 2nd column
#
# b) Access 3rd row, 1st column

# %%
import numpy as np;
arr=np.array([[10, 20, 30,100], [40, 50, 60,200], [70, 80, 90,300]])
x,y=arr.shape
print("the first row is ")
for i in range(0,y):
  print(arr[0][i],end=" ")
print()
print()

print("the second column is ")
for i in range(0,x):
  print(arr[i][1],end=" ")
print()
print()

print("the third row is ")
for i in range(0,y):
  print(arr[2][i],end=" ")
print()
print()

print("the first column is ")
for i in range(0,x):
  print(arr[i][0],end=" ")
print()
print()
# Out:
# the first row is
# 10 20 30 100
#
# the second column is
# 20 50 80
#
# the third row is
# 70 80 90 300
#
# the first column is
# 10 40 70

# %% [markdown]
# Q.4 Write program to create an 1-D NumPy array named <<Your Name>> with evenly
# spaced 25 numbers from 10 to 100 using linspace(). Print the dimensions of the array,
# shape, total elements, the data type of each element and total number of bytes consumed
# by the array. Find the transpose of this array using reshape() attribute. Can we do the same
# with T attribute?

# %%
import numpy as np
import random

karan=np.linspace(10,100,25)
print (karan)
print("the dimensions are: ")
print(karan.ndim)
print()
print("the shape of the array is ")
print(karan.shape)
print()
print("array size is :")
print(karan.size)
print()
print("data type of the array is :")
print(karan.dtype)
print()
print("the number of bytes occupied by array is :")
print(karan.nbytes)
print()
transpose_karan = karan.reshape(25, 1)
print("the shape of the transposed array is ")
print(transpose_karan.shape)
# Out:
# [ 10.    13.75  17.5   21.25  25.    28.75  32.5   36.25  40.    43.75
#   47.5   51.25  55.    58.75  62.5   66.25  70.    73.75  77.5   81.25
#   85.    88.75  92.5   96.25 100.  ]
# the dimensions are:
# 1
#
# the shape of the array is
# (25,)
#
# array size is :
# 25
#
# data type of the array is :
# float64
#
# the number of bytes occupied by array is :
# 200
#
# the shape of the transposed array is
# (25, 1)

# %% [markdown]
# Q5. Create a 2-D Array of three rows and four columns, named ucs420_<your_name>>
# with following values – 10, 20, 30, 40, 50, 60, 70, 80, 90, 15, 20, 35. Compute the mean,
# median, max, min, unique elements. Reshape the array to four rows and three columns and
# name it as reshaped_ ucs420_<your_name>>. Resize the array to two rows and three
# columns and name it as resized_ ucs420_<your_name>>.

# %%
import numpy as np
ucs420_karan=np.array([[10, 20, 30, 40],[50, 60, 70, 80],[90, 15, 20, 35]])
sum=0
r,c=ucs420_karan.shape
for i in range(r):
  for j in range(c):
    sum=sum+ucs420_karan[i][j]

print ("the mean is ",sum/ucs420_karan.size)
ll=[]
for i in range(r):
  for j in range(c):
    ll.append(ucs420_karan[i][j])

ll.sort()
size=len(ll)
print("the median of the array is: ")
if(size%2!=0):
  print(ll[size//2])

else:
  print((ll[size//2]+ll[(size//2)+1])/2)

print("the max ele in the array is: ",ucs420_karan.max())
print("the min ele in the array is: ",ucs420_karan.min())
print("the unique ele are: ")
i = 0
while i<len(ll)-1:
  if ll[i]==ll[i+1]:
    ele=ll[i]
    i+=1
    while i<len(ll) and ll[i]==ele:
      i+=1
  else:
    print(ll[i],end=" ")
    i+=1
if i==len(ll)-1:
    print(ll[i])
# Out:
# the mean is  43.333333333333336
# the median of the array is:
# 45.0
# the max ele in the array is:  90
# the min ele in the array is:  10
# the unique ele are:
# 10 15 30 35 40 50 60 70 80 90
